# %%
# %matplotlib inline
import cv2

import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("keji.jpg", cv2.IMREAD_GRAYSCALE)
f = np.fft.fft2(img)
#进行频率变换，得到图像中心频率
fshift=np.fft.fftshift(f)
#构建振幅谱,输出数组绝对值的log
magnitude_spectrum=20*np.log(np.abs(fshift))
#把显示界面分割成1*2的网格，121将参数合起来写，1是行数，2是列数，最后一个1是标号
plt.subplot(121),plt.imshow(img,cmap="gray")#cmap是将标量数据映射成色彩图
plt.title("input image"),plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum,cmap="gray")
plt.title("magnitude spectrum"),plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# IMG -> decompose -> Content & style -> compose
#
# IMG -> decompose 19 elements (content & style) -> 19 recompose ->
#
# Easy understanding, several idnetical objects, crop and paste (segment and )
#
# ### Understanding of multi-object/multi-region data augmentation (have hard border/ no hard border)
#
# how to expand the augment range
#
# single object landmark detection -> distillation -> multi-task
#
# ### Two stage:
# First: coarse; Second: Fined
