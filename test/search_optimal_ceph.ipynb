# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np


data = np.load("../cache/optimal_brct_im.npy", allow_pickle=True)
data = data.tolist()
# print(data)
df = pd.DataFrame.from_dict(data)
df['mre_gap'] = df['mre_lm'] - df["mre_lm2"]
print(df)
xlabel = "cj_ct_floor"
ylabel = "cj_br_floor"
fig = sns.scatterplot(x=xlabel, y=ylabel, data=df)
sns.regplot(x=xlabel, y=ylabel, data=df)

sns.scatterplot(x=xlabel, y=ylabel, data=df[7:8], color="red")
sns.scatterplot(x=xlabel, y=ylabel, data=df[17:18], color="black")
print(df[0:1])

# scatter_fig = fig.get_figure()
# scatter_fig.savefig("./tmp/_search_optimal_ceph.png")
# Out:
#     index   mi_mean    mi_std  miself_mean  miself_std  entr_mean  entr_std  \
# 0       0  0.588559  0.263882     2.511389    0.460767   4.329226  0.321048
# 1       1  0.968984  0.120061     3.180646    0.305745   4.949556  0.360155
# 2       2  0.884231  0.126968     3.193668    0.284521   4.940222  0.250011
# 3       3  0.415958  0.312459     2.113342    0.481003   4.133694  0.348265
# 4       4  0.934675  0.103588     3.261820    0.247130   5.029374  0.221535
# 5       5  0.875207  0.204228     2.729021    0.758167   4.461311  0.539590
# 6       6  0.753550  0.215996     2.163121    0.750609   4.123973  0.446129
# 7       7  0.690978  0.188207     1.943289    0.650670   4.070845  0.393772
# 8       8  0.707062  0.191575     2.015322    0.679332   4.084047  0.409551
# 9       9  0.961788  0.137256     3.261124    0.237044   4.886449  0.278280
# 10     10  0.957816  0.114654     3.208136    0.361651   4.870442  0.335603
# 11     11  0.960945  0.122418     3.165524    0.382367   4.798717  0.348146
# 12     12  0.986393  0.116023     3.126978    0.302674   4.706702  0.330469
# 13     13  0.890740  0.192131     2.646139    0.602976   4.297014  0.419127
# 14     14  0.964993  0.092190     3.251242    0.246027   4.944522  0.268628
# 15     15  0.714070  0.187529     1.974821    0.604595   4.050917  0.385502
# 16     16  0.933294  0.121056     3.206975    0.211639   5.037180  0.172057
# 17     17  0.918915  0.101705     3.224848    0.244092   5.017952  0.208779
# 18     18  0.727131  0.282873     2.663787    0.471451   4.531976  0.321038
#
#     cj_br_ceil  cj_ct_ceil  cj_br_floor  cj_ct_floor  new_entr  mre_lm  \
# 0     1.784600    2.046133     0.608000     0.477333  5.039549  1.3990
# 1     1.529000    1.705333     0.570600     0.427467  6.331593  1.5526
# 2     1.687400    1.916533     0.539400     0.385867  6.425630  1.7562
# 3     2.235400    2.647200     0.537000     0.382667  4.319388  2.9915
# 4     1.522800    1.697067     0.578600     0.438133  5.888620  1.7145
# 5     1.685000    1.913333     0.534000     0.378667  5.745287  1.9027
# 6     1.834000    2.112000     0.499600     0.332800  5.302986  1.8260
# 7     1.910000    2.213333     0.485800     0.314400  5.908083  1.3118
# 8     1.863400    2.151200     0.495200     0.326933  5.494010  1.1585
# 9     1.602800    1.803733     0.578000     0.437333  5.892994  4.4261
# 10    1.485000    1.646667     0.595400     0.460533  6.512389  2.2153
# 11    1.471000    1.628000     0.603600     0.471467  6.178415  2.8174
# 12    1.278867    1.376267     0.706067     0.612533  4.591006  1.5348
# 13    1.462800    1.617067     0.630000     0.506667  4.724420  1.9849
# 14    1.344933    1.462133     0.666133     0.557067  4.418108  1.3075
# 15    1.712000    1.949333     0.553200     0.404267  4.744050  1.8713
# 16    1.540000    1.720000     0.595200     0.460267  6.057477  1.5415
# 17    1.552000    1.736000     0.569000     0.425333  5.061216  3.7358
# 18    1.952800    2.270400     0.534000     0.378667  6.098650  2.3073
#
#     mre_lm2  mre_gap
# 0    1.6767  -0.2777
# 1    1.7246  -0.1720
# 2    2.2157  -0.4595
# 3    2.5067   0.4848
# 4    1.9819  -0.2674
# 5    2.2091  -0.3064
# 6    1.7173   0.1087
# 7    1.3327  -0.0209
# 8    1.6392  -0.4807
# 9    2.2740   2.1521
# 10   1.6451   0.5702
# 11   1.7791   1.0383
# 12   1.5442  -0.0094
# 13   1.7209   0.2640
# 14   1.8208  -0.5133
# 15   2.9706  -1.0993
# 16   1.8948  -0.3533
# 17   1.9768   1.7590
# 18   2.1830   0.1243
#    index   mi_mean    mi_std  miself_mean  miself_std  entr_mean  entr_std  \
# 0      0  0.588559  0.263882     2.511389    0.460767   4.329226  0.321048
#
#    cj_br_ceil  cj_ct_ceil  cj_br_floor  cj_ct_floor  new_entr  mre_lm  \
# 0      1.7846    2.046133        0.608     0.477333  5.039549   1.399
#
#    mre_lm2  mre_gap
# 0   1.6767  -0.2777

# %%
data = np.load("../cache/optimal_brct_im.npy", allow_pickle=True)
data = data.tolist()
df = pd.DataFrame.from_dict(data)
df = df[df['entr_mean']>=4.5]
print(df['cj_br_floor'].mean(), df['cj_br_ceil'].mean(), df['cj_ct_floor'].mean(), df['cj_ct_ceil'].mean())
# Out:
# 0.5941818181818173 1.5424181818181808 0.4595151515151508 1.7238303030303037

# %%
xlabel = "new_entr"
ylabel = "cj_br_ceil"
fig = sns.scatterplot(x=xlabel, y=ylabel, data=df)
sns.regplot(x=xlabel, y=ylabel, data=df)
# Out:
# <AxesSubplot:xlabel='new_entr', ylabel='cj_br_ceil'>

# %%
xlabel = "mi_mean"
ylabel = "cj_br_ceil"
fig = sns.scatterplot(x=xlabel, y=ylabel, data=df)
sns.regplot(x=xlabel, y=ylabel, data=df)
# Out:
# <AxesSubplot:xlabel='mi_mean', ylabel='cj_br_ceil'>

# %%
xlabel = "entr_mean"
# ylabel = "mi_mean"
ylabel = "cj_br_ceil"
fig = sns.scatterplot(x=xlabel, y=ylabel, data=df)
sns.regplot(x=xlabel, y=ylabel, data=df)
fig.set_xlabel("Entropy")
fig.set_ylabel("Brightness")
# Out:
# Text(0, 0.5, 'Brightness')

# %%
xlabel = "entr_mean"
ylabel = "mre_gap"
fig = sns.scatterplot(x=xlabel, y=ylabel, data=df)
sns.regplot(x=xlabel, y=ylabel, data=df)
# Out:
# <AxesSubplot:xlabel='entr_mean', ylabel='mre_gap'>
